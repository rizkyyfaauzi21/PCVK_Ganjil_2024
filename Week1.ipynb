# %% [markdown]
# <a href="https://colab.research.google.com/github/rizkyyfaauzi21/PCVK_Ganjil_2024/blob/main/Week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %%
# Membuat list untuk menyimpan url dari beberapa image
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
        "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
        "https://d1tgyzt3mf06m9.cloudfront.net/production/media/2017/oktober/10-gundam-transfor/gundam-transformasi-1-700x700.jpg"]
# baca dan tampilkan image
# loop pada tiap url image, beberapa image dapat disimpan pada list
for url in urls:
  image = io.imread(url) #read image
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5) #resize image to half size
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB) #convert color to RGB
  final_frame = cv.hconcat((image, image_2)) #concatenate image
  cv2_imshow(final_frame) #show image
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=680x200>

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi image: tinggi x lebar = ",tinggi," x ",lebar)
cv2_imshow(image_2)
# Out:
# resolusi image: tinggi x lebar =  200  x  340
# <PIL.Image.Image image mode=RGB size=340x200>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#membuat garis horizontal ditengah image
for y in range (lebar):
  image_3[int((tinggi)/2),y]=[255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=680x200>

# %% [markdown]
# Pertanyaan :
# 1. Jelaskan, mengapa pada modul praktikum ini eksekusi kode Python dilakukan
# menggunakan Google Colab?
#
# 2. Jelaskan mengenai kegunaan setiap library pada praktikum langkah ke delapan?
# Apakah semua library tersebut harus digunakan dalam praktikum sesi ini?
#
# 3. Pada uji coba langkah ke-9 terdapat potongan kode program sebagai berikut:
#   image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
#   Apa kegunaan kode program tersebut?dan apa pengaruhnya jika tidak dilakukan?
#
# 4. Perhatikan potongan kode progam berikut:
#   for y in range (lebar):
#   image_3[int((tinggi)/2),y] = [255,255,255]
#   Apakah kegunaan kode [255,255,255] ? Jelaskan!
#
# 5. Jelaskan keterkaitan antara pixel dan juga resolusi gambar yang tinggi ataupun rendah!
#
# Jawab :
# 1. Karena menggunakan google colab lebih mudah dan langsung bisa menggunakan library tanpa harus menginstal libray nya
#
# 2. -NumPy: Untuk komputasi numerik dan manipulasi array.
#   -Pandas: Untuk manipulasi dan analisis data tabular.
#   -OpenCV: Untuk pemrosesan gambar dan video.
#   -Google Colab Patches: Untuk menampilkan gambar di Google Colab.
#   -scikit-image: Untuk pemrosesan dan transformasi gambar.
#   -Pillow: Untuk manipulasi dan pengolahan gambar.
#   -Matplotlib: Untuk membuat dan menampilkan grafik serta visualisasi data.
#
#   Library yang tidak digunakan yaitu pandas dan mathplotib
#
# 3. Kegunaannya yaitu mengubah ukuran gambar menjadi 50% dari ukuran aslinnya, jika tidak dilakukan maka gamabr akan tampil sesuai ukuran aslinya
#
# 4. [255,255,255]: Ini adalah nilai RGB untuk warna putih. Kegunaannya untuk menggambar garis horizontal putih di tengah gambar image_3
#
# 5. Pixel adalah titik kecil yang membentuk gambar digital. Resolusi adalah jumlah total pixel dalam gambar. Semakin tinggi resolusi, semakin banyak pixel dalam gambar, yang berarti gambar akan lebih jelas dan detail. Gambar beresolusi rendah memiliki lebih sedikit pixel, sehingga cenderung terlihat buram atau kurang detail saat diperbesar.

# %% [markdown]
# #TUGAS
# 1. Lakukan langkah-langkah praktikum seperti diatas
# 2. Buat garis vertikal dan garis menyilang diagonal pada image keluaran

# %%
# urls = ["https://d1tgyzt3mf06m9.cloudfront.net/production/media/2017/oktober/10-gundam-transfor/gundam-transformasi-1-700x700.jpg"]
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_4 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#membuat garis horizontal ditengah image
for x in range (tinggi):
  image_4[x,int((lebar)/2)]=[255,255,255]

final_frame = cv.hconcat((image_2, image_4))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=340x100>

# %%
# urls = ["https://d1tgyzt3mf06m9.cloudfront.net/production/media/2017/oktober/10-gundam-transfor/gundam-transformasi-1-700x700.jpg"]
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_5 = cv.cvtColor(image, cv.COLOR_BGR2RGB)


#Garis diagonal dari kiri ke kanan
for y in range(tinggi):
  x = int(lebar/tinggi*y)
  image_5[y, x] = [255,255,255]

#Garis diagonal dari kanan ke kiri
for y in range(tinggi):
  x = int((lebar/tinggi)*(tinggi-y-1))
  image_5[y, x] = [255,255,255]

final_frame = cv.hconcat((image_2, image_5))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=340x100>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_6 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#Buat garis horizontal di tengah dengan panjang tertentu
garis_tengah = tinggi/2
panjang_garis = lebar/4

titik_awal = (lebar - panjang_garis)/2
titik_akhir = titik_awal + panjang_garis

for y in range(int(titik_awal), int(titik_akhir)):
  image_6[int(garis_tengah), y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_6))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=340x100>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_7 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# Definisikan titik awal dan titik akhir
titik_awal = 50  # Misalnya, 50 piksel dari tepi
titik_akhir = 100  # Misalnya, 200 piksel dari tepi

# Pastikan titik_awal dan titik_akhir dalam rentang dimensi gambar
titik_awal = max(0, titik_awal)
titik_akhir = min(image_7.shape[1], titik_akhir)  # Batasi hingga lebar gambar

# Gambar kotak putih
for y in range(titik_awal, titik_akhir):
    for x in range(titik_awal, titik_akhir):
        if y < image_7.shape[0] and x < image_7.shape[1]:  # Pastikan dalam batas gambar
            image_7[y, x] = [255, 255, 255]

# Menggabungkan gambar secara horizontal
final_frame = cv.hconcat([image_2, image_7])
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=340x100>

# %% [markdown]
# #TUAGS KELOMPOK
# 1. Akses file image lokal (KTP/SIM) dan tampilkan menggunakan OpenCV dan Matplotlib
# 2. Identifikasi kenapa menggunakan konversi warna BGR2RGB pada matplotlib dan tanpa
# konversi pada opencv
# 3. Tutup tiap bagian tertentu dari kartu identitas tersebut. Kelompok 1 tutup bagian nomor NIK dan nama. Kelompok 2 tutup bagian TTL dan Jenis Kelamin. Kelompok 3 tutup bagian Gol. Darah dan TTD. Kelompok 4 tutup bagian Alamat dan Kecamatan. Kelompok 5 tutup bagian Agama dan Status Kawin. Kelompok 6 tutup Pekerjaan dan kewarganegaraan. Kelompok 7 tutup bagian berlaku hingga dan foto. Kelompok 8 tutup bagian kabupaten dan tanggal dikeluarkan KTP yang ada dibagian bawah foto. Kelompok 9 tutup bagian nama propinsi dan kabupaten di bagian paling atas KTP. Kelompok 10 tutup bagian RT/RW dan Kel/desa. Tutup menggunakan 2 kotak warna yang berbeda. Tidak boleh menggunakan fungsi rectangle openCV, fungsi ini akan dipelajari pada pertemuan 2.

# %%
url = "https://umsu.ac.id/artikel/wp-content/uploads/2023/11/cara-mudah-cek-ktp-asli-atau-palsu-718x375.jpeg"
image = io.imread(url)                            #read image
image = cv.resize((image), (0,0) , fx=0.5, fy=0.5)
image_8 = cv.cvtColor(image, cv.COLOR_BGR2RGB)    #convert color to RGB

tinggi = image_8.shape[0]
lebar = image_8.shape[1]
print("resolusi image: tinggi x lebar = ", tinggi, " x ", lebar)
cv2_imshow(image_8)

x_start = 40
x_end = 50

y_start = 110
y_end = 230
image_8[x_start:x_end, y_start:y_end] = [0,0,0]

a_start = 53
a_end = 63

b_start = 115
b_end = 175
image_8[a_start:a_end, b_start:b_end] = [255,0,255]
cv2_imshow(image_8)
# Out:
# resolusi image: tinggi x lebar =  188  x  359
# <PIL.Image.Image image mode=RGB size=359x188>
# <PIL.Image.Image image mode=RGB size=359x188>
